# %% [markdown]
# # Collatz's Hypothesis
#
#   ## In 1937, a German mathematician named Lothar Collatz formulated an intriguing hypothesis (it still remains unproven)
#
# ### Real-World Mathematical Problem
#
# **Author:** Tejesh
#
# This notebook explores the famous Collatz Conjecture, also known as the **3n + 1 problem**, using Python.

# %% [markdown]
# ## Scenario
#
#   - Take any non-negative and non-zero integer number and name it c0;
#   - If it's even, evaluate a new c0 as c0 ÷ 2;
#   - Otherwise, if it's odd, evaluate a new c0 as 3 × c0 + 1;
#   - If c0 ≠ 1, go back to point 2.
#
# The hypothesis says that regardless of the initial value of c0, it will always go to 1.Of course, it's an extremely complex task to use a computer in order to prove the hypothesis for any natural number (it may even require artificial intelligence), but you can use Python to check some individual numbers. Maybe you'll even find the one which would disprove the hypothesis.
#
# #### Write a program which reads one natural number and executes the above steps as long as c0 remains different from 1. We also want you to count the  steps needed to achieve the goal. Your code should output all the intermediate values of c0, too.

# %%
c0=int(input())
print("Entered input number:", c0)
if c0<=0:
    print("invalid")
steps=0
while c0!=1:
    if c0 % 2 == 0:
        c0=c0/2
    else:
        c0=(3*c0)+1
    print(c0)
    steps+=1
print("Steps: ", steps)
# Out:
# Entered input number: 12
# 6.0
# 3.0
# 10.0
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0
# Steps:  9

# %% [markdown]
# ## Conclusion
#
# The Collatz Conjecture demonstrates how a very simple set of rules can generate surprisingly intricate numerical behavior.
#
# Although extensive computational experiments suggest that every positive integer eventually reaches 1, a complete mathematical proof remains unknown.
#
# This implementation provides practical insight into iterative algorithms, conditional statements, loops, and problem-solving using Python.
